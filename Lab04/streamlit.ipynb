# %%
import streamlit as st
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# 1. Load your text documents
with open("documents.txt", "r", encoding="utf-8") as f:
    documents = [line.strip() for line in f.readlines()]

# 2. Load a pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

# 3. Generate embeddings
embeddings = model.encode(documents)

# 4. Save to the filename your original script expects
np.save("embeddings.npy", embeddings)
print("embeddings.npy has been created!")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1698.69it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# embeddings.npy has been created!
